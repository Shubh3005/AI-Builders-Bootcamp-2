# %%
from IPython.display import display, Markdown
from openai import OpenAI

from markdown import markdown
import requests

# %%
# Open and read the Markdown file
with open("resume.md", "r", encoding="utf-8") as file:
    resume_string = file.read()

# display resume
display(Markdown(resume_string))
# Out:
# # Udit Mohanty
#
# [Website](https://github.com/Shubh3005/AI-Builders-Bootcamp-2)
#
# [LinkedIn](https://www.linkedin.com/in/udit-mohanty-8970011a7/)
#
# **Phone**: +1(562) 284-9254
#
# **Email**: udit.mohanty01@student.csulb.edu
#
# **Location**: Long Beach,CA-90815
#
# ---
#
# ## Aspiring Cloud Engineer
#
# Accomplished AWS Cloud Engineer and DevOps professional with over two years of experience in designing, deploying, and automating scalable, secure cloud infrastructure solutions. Known for delivering excellent results in fast-paced environments, with proven expertise in AWS and Azure platforms, scripting (Python, Bash), Infrastructure as Code (Terraform, CloudFormation), and containerization (Docker, Kubernetes), as well as handson project experience deploying complex architectures and automating CI/CD pipelines. Recognized for orchestrating successful cloud migrations and process automation, ensuring zero downtime and enhanced system security, while maintaining a strong commitment to continuous improvement and Agile methodologies. Exceptional trainign and academic qualifications, including a M.Sc. candidacy in Information Systems along with multiple AWS and Azure certifications.
#
# ---
#
# ## Education
#
# **California State University long Beach**
#
# _College of Business_
#
# **Expected Graduation**: May 2025
#
# **GPA**: 3.8/4.00
#
# ---
#
# ## Experience
#
# **Cognizant Technology Solutions**
#
# Devops Engineer
#
# _April 2021 – June 2023_
#
# - Charted successful course of automating the deployment pipeline by integrating Jenkins for Continuous Integration (CI) and FluxCD for Continuous Deployment (CD), reducing deployment time while ensuring faster and more reliable software releases.
#
# - Orchestrated a zero-downtime migration of Real-Time Bidding (RTB) infrastructure from AWS to Google Cloud Platform (GCP).
#
# - Executed a seamless migration of critical AWS production databases from AWS RDS to Google Cloud SQL with Database Migration Service (DMS), effectively improving data accessibility and continuity without impacting ongoing operations.
#
# ---
#
# ## Certifications
#
# - AWS Cloud Practioner
#
# - AWS Solutions Architect Associate
#
# - Microsoft Certified Azure Fundamentals
#
# - AWS Devops Professional
#
# ---
#
# ## Skills
#
# - **Languages**: JavaScript, Python,Node.js
#
# - **CLOUD & IAC**:AWS (EC2, Lambda, CloudFormation), Azure (VMs, ARM, Blob), Terraform
#
# - **CI/CD & AUTOMATION**: Jenkins, GitHub Actions, Ansible, Python, Bash
#
# - **CONTAINERS & ORCHESTRATION**: Docker, Kubernetes (EKS, AKS)
#
# - **DATABASES & SQL**: SQL, PostgreSQL, MySQL, DynamoDB
#
# - **DATA MANIPULATION & ANALYSIS**: Python (Pandas, NumPy), and Excel for data analysis and manipulation.
#
# ---
#
# ## Projects and Research
#
# ### IMPLEMENTATION OF FLASK APPLICATION ON AWS EC2 INSTANCE USING TERRAFORM PROVISIONING
#
# _SEPT 2023-OCT 2023_
#
# - Established a local Integrated Development Environment (IDE) on Linux, then configured and initialized Terraform for infrastructure management.
#
# - Utilized VS Code for efficient code creation and error correction, ensuring smooth deployment processes.
#
# - Created AWS EC2 instance, Internet Gateway, subnet, and security groups to facilitate inbound and outbound network traffic.
#
# - Orchestrated a successful Flask application deployment on an AWS EC2 instance.
#
# - GitHub link: https://github.com/uditmohanty/Flask-App
#
# ### IMPLEMENTATION OF TWO-TIER ARCHITECTURE ON AWS DEPLOY WEBSITE
#
# _JAN 2024- MARCH 2024_
#
# - Demonstrated expertise in installing essential plugins and initializing Terraform on a local machine.
#
# - Designed a VPC with security groups and public subnets using Terraform, ensuring secure and isolated network layers.
#
# - Provisioned EC2 instances for web and database layers; implemented a database in a subnet using Terraform to enhance security.
#
# - Configured a load balancer to optimize traffic distribution for the web application; established SSH access by sharing public keys.
#
# - GitHub link: https://github.com/uditmohanty/2-tier-architecure-on-aws-using-terraform
#
# ### E-COMMERCE WEB SITE ON AWS EKS USING TERRAFORM PROVISIONING
#
# _MAY 2024-AUG 2024_
#
# - Established a system for initialization and configuration; verified the configuration of pre-installed tools
#
# - Created a VPC with subnets and security groups, then set up an EC2 instance for Kubernetes (EKS) client-server interactions.
#
# - Configured kubectl for EKS cluster management and facilitated handling of master and worker nodes.
#
# - Developed and deployed deployment.yaml and service.yaml files for seamless e-commerce site deployment; integrated a load balancer for
#   optimal traffic management.
#
# - GitHub link: https://github.com/uditmohanty/My-EKS-Terraform-Project
#
# ---

# %%
# input job description
jd_string = "Assumes responsibility for day-to-day administration and participation of MCH Covered Entities in the 340B Drug Pricing Program. Manages and optimizes the financial performance of the 340B Drug Pricing Program. Analyzes data and contributes to strategic decision-making for the 340B Drug Pricing Program. Ensures compliance with program regulations."

# %%
prompt_template = lambda resume_string, jd_string : f"""
You are a professional resume optimization expert specializing in tailoring resumes to specific job descriptions. Your goal is to optimize my resume and provide actionable suggestions for improvement to align with the target role.

### Guidelines:
1. **Relevance**:
   - Prioritize experiences, skills, and achievements **most relevant to the job description**.
   - Remove or de-emphasize irrelevant details to ensure a **concise** and **targeted** resume.
   - Limit work experience section to 2-3 most relevant roles
   - Limit bullet points under each role to 2-3 most relevant impacts

2. **Action-Driven Results**:
   - Use **strong action verbs** and **quantifiable results** (e.g., percentages, revenue, efficiency improvements) to highlight impact.

3. **Keyword Optimization**:
   - Integrate **keywords** and phrases from the job description naturally to optimize for ATS (Applicant Tracking Systems).

4. **Additional Suggestions** *(If Gaps Exist)*:
   - If the resume does not fully align with the job description, suggest:
     1. **Additional technical or soft skills** that I could add to make my profile stronger.
     2. **Certifications or courses** I could pursue to bridge the gap.
     3. **Project ideas or experiences** that would better align with the role.

5. **Formatting**:
   - Output the tailored resume in **clean Markdown format**.
   - Include an **"Additional Suggestions"** section at the end with actionable improvement recommendations.

---

### Input:
- **My resume**:
{resume_string}

- **The job description**:
{jd_string}

---

### Output:
1. **Tailored Resume**:
   - A resume in **Markdown format** that emphasizes relevant experience, skills, and achievements.
   - Incorporates job description **keywords** to optimize for ATS.
   - Uses strong language and is no longer than **one page**.

2. **Additional Suggestions** *(if applicable)*:
   - List **skills** that could strengthen alignment with the role.
   - Recommend **certifications or courses** to pursue.
   - Suggest **specific projects or experiences** to develop.
"""

# %%
prompt = prompt_template(resume_string, jd_string)

# %%
print(prompt)
# Out:
# You are a professional resume optimization expert specializing in tailoring resumes to specific job descriptions. Your goal is to optimize my resume and provide actionable suggestions for improvement to align with the target role.
#
# ### Guidelines:
# 1. **Relevance**:
#    - Prioritize experiences, skills, and achievements **most relevant to the job description**.
#    - Remove or de-emphasize irrelevant details to ensure a **concise** and **targeted** resume.
#    - Limit work experience section to 2-3 most relevant roles
#    - Limit bullet points under each role to 2-3 most relevant impacts
#
# 2. **Action-Driven Results**:
#    - Use **strong action verbs** and **quantifiable results** (e.g., percentages, revenue, efficiency improvements) to highlight impact.
#
# 3. **Keyword Optimization**:
#    - Integrate **keywords** and phrases from the job description naturally to optimize for ATS (Applicant Tracking Systems).
#
# 4. **Additional Suggestions** *(If Gaps Exist)*:
#    - If the resume does not fully align with the job description, suggest:
#      1. **Additional technical or soft skills** that I could add to make my profile stronger.
#      2. **Certifications or courses** I could pursue to bridge the gap.
#      3. **Project ideas or experiences** that would better align with the role.
#
# 5. **Formatting**:
#    - Output the tailored resume in **clean Markdown format**.
#    - Include an **"Additional Suggestions"** section at the end with actionable improvement recommendations.
#
# ---
#
# ### Input:
# - **My resume**:
# # Udit Mohanty
#
# [Website](https://github.com/Shubh3005/AI-Builders-Bootcamp-2)
#
# [LinkedIn](https://www.linkedin.com/in/udit-mohanty-8970011a7/)
#
# **Phone**: +1(562) 284-9254
#
# **Email**: udit.mohanty01@student.csulb.edu
#
# **Location**: Long Beach,CA-90815
#
# ---
#
# ## Aspiring Cloud Engineer
#
# Accomplished AWS Cloud Engineer and DevOps professional with over two years of experience in designing, deploying, and automating scalable, secure cloud infrastructure solutions. Known for delivering excellent results in fast-paced environments, with proven expertise in AWS and Azure platforms, scripting (Python, Bash), Infrastructure as Code (Terraform, CloudFormation), and containerization (Docker, Kubernetes), as well as handson project experience deploying complex architectures and automating CI/CD pipelines. Recognized for orchestrating successful cloud migrations and process automation, ensuring zero downtime and enhanced system security, while maintaining a strong commitment to continuous improvement and Agile methodologies. Exceptional trainign and academic qualifications, including a M.Sc. candidacy in Information Systems along with multiple AWS and Azure certifications.
#
# ---
#
# ## Education
#
# **California State University long Beach**
#
# _College of Business_
#
# **Expected Graduation**: May 2025
#
# **GPA**: 3.8/4.00
#
# ---
#
# ## Experience
#
# **Cognizant Technology Solutions**
#
# Devops Engineer
#
# _April 2021 – June 2023_
#
# - Charted successful course of automating the deployment pipeline by integrating Jenkins for Continuous Integration (CI) and FluxCD for Continuous Deployment (CD), reducing deployment time while ensuring faster and more reliable software releases.
#
# - Orchestrated a zero-downtime migration of Real-Time Bidding (RTB) infrastructure from AWS to Google Cloud Platform (GCP).
#
# - Executed a seamless migration of critical AWS production databases from AWS RDS to Google Cloud SQL with Database Migration Service (DMS), effectively improving data accessibility and continuity without impacting ongoing operations.
#
# ---
#
# ## Certifications
#
# - AWS Cloud Practioner
#
# - AWS Solutions Architect Associate
#
# - Microsoft Certified Azure Fundamentals
#
# - AWS Devops Professional
#
# ---
#
# ## Skills
#
# - **Languages**: JavaScript, Python,Node.js
#
# - **CLOUD & IAC**:AWS (EC2, Lambda, CloudFormation), Azure (VMs, ARM, Blob), Terraform
#
# - **CI/CD & AUTOMATION**: Jenkins, GitHub Actions, Ansible, Python, Bash
#
# - **CONTAINERS & ORCHESTRATION**: Docker, Kubernetes (EKS, AKS)
#
# - **DATABASES & SQL**: SQL, PostgreSQL, MySQL, DynamoDB
#
# - **DATA MANIPULATION & ANALYSIS**: Python (Pandas, NumPy), and Excel for data analysis and manipulation.
#
# ---
#
# ## Projects and Research
#
# ### IMPLEMENTATION OF FLASK APPLICATION ON AWS EC2 INSTANCE USING TERRAFORM PROVISIONING
#
# _SEPT 2023-OCT 2023_
#
# - Established a local Integrated Development Environment (IDE) on Linux, then configured and initialized Terraform for infrastructure management.
#
# - Utilized VS Code for efficient code creation and error correction, ensuring smooth deployment processes.
#
# - Created AWS EC2 instance, Internet Gateway, subnet, and security groups to facilitate inbound and outbound network traffic.
#
# - Orchestrated a successful Flask application deployment on an AWS EC2 instance.
#
# - GitHub link: https://github.com/uditmohanty/Flask-App
#
# ### IMPLEMENTATION OF TWO-TIER ARCHITECTURE ON AWS DEPLOY WEBSITE
#
# _JAN 2024- MARCH 2024_
#
# - Demonstrated expertise in installing essential plugins and initializing Terraform on a local machine.
#
# - Designed a VPC with security groups and public subnets using Terraform, ensuring secure and isolated network layers.
#
# - Provisioned EC2 instances for web and database layers; implemented a database in a subnet using Terraform to enhance security.
#
# - Configured a load balancer to optimize traffic distribution for the web application; established SSH access by sharing public keys.
#
# - GitHub link: https://github.com/uditmohanty/2-tier-architecure-on-aws-using-terraform
#
# ### E-COMMERCE WEB SITE ON AWS EKS USING TERRAFORM PROVISIONING
#
# _MAY 2024-AUG 2024_
#
# - Established a system for initialization and configuration; verified the configuration of pre-installed tools
#
# - Created a VPC with subnets and security groups, then set up an EC2 instance for Kubernetes (EKS) client-server interactions.
#
# - Configured kubectl for EKS cluster management and facilitated handling of master and worker nodes.
#
# - Developed and deployed deployment.yaml and service.yaml files for seamless e-commerce site deployment; integrated a load balancer for
#   optimal traffic management.
#
# - GitHub link: https://github.com/uditmohanty/My-EKS-Terraform-Project
#
# ---
#
#
# - **The job description**:
# Assumes responsibility for day-to-day administration and participation of MCH Covered Entities in the 340B Drug Pricing Program. Manages and optimizes the financial performance of the 340B Drug Pricing Program. Analyzes data and contributes to strategic decision-making for the 340B Drug Pricing Program. Ensures compliance with program regulations.
#
# ---
#
# ### Output:
# 1. **Tailored Resume**:
#    - A resume in **Markdown format** that emphasizes relevant experience, skills, and achievements.
#    - Incorporates job description **keywords** to optimize for ATS.
#    - Uses strong language and is no longer than **one page**.
#
# 2. **Additional Suggestions** *(if applicable)*:
#    - List **skills** that could strengthen alignment with the role.
#    - Recommend **certifications or courses** to pursue.
#    - Suggest **specific projects or experiences** to develop.

# %%
# setup OpenAPI api client
client = OpenAI(api_key="sk-PMruo4v4FzLGKlS6UEnd7bbTtazg-qVmJAl8zLpBbIT3BlbkFJf_x9egDnrY3wFRdA08x9qXxR2RafsBsgt364cSX40A")
# client = OpenAI(
#     api_key="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",
#     organization='org-kRR5REFQ4Lb2S34LdZwXsS7a',
#     project='proj_lwJEdrqqCtQRc3mKDuKahzPW',)
# extract response
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[        {"role": "system", "content": "Expert resume writer"},
        {"role": "user", "content": prompt}],
  response_format={
    "type": "text"
  },
  temperature=.7,
  max_completion_tokens=2048,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
response_string = response.choices[0].message.content
# display the response
display(Markdown(response_string))
# Out:
# # Udit Mohanty
#
# [Website](https://github.com/Shubh3005/AI-Builders-Bootcamp-2) | [LinkedIn](https://www.linkedin.com/in/udit-mohanty-8970011a7/)
# **Phone**: +1(562) 284-9254 | **Email**: udit.mohanty01@student.csulb.edu
# **Location**: Long Beach, CA 90815
#
# ---
#
# ## Aspiring Cloud Engineer
#
# Detail-oriented AWS Cloud Engineer with over two years of experience in managing and optimizing cloud infrastructure solutions. Proven ability to analyze data effectively and contribute to strategic decision-making while ensuring compliance with program regulations. Exceptional skills in AWS, Azure, and Infrastructure as Code (Terraform, CloudFormation). Recognized for migrating complex architectures and automating CI/CD pipelines with a strong commitment to continuous improvement in fast-paced environments. M.Sc. candidate in Information Systems with several AWS and Azure certifications.
#
# ---
#
# ## Education
#
# **California State University, Long Beach**
# _M.Sc. in Information Systems_ | Expected Graduation: May 2025
# **GPA**: 3.8/4.00
#
# ---
#
# ## Experience
#
# **Cognizant Technology Solutions**
# _DevOps Engineer_
# _April 2021 – June 2023_
#
# - Enhanced financial performance of cloud infrastructure by automating deployment pipelines with Jenkins and FluxCD, reducing deployment time by 30%.
# - Analyzed and executed a zero-downtime migration of Real-Time Bidding (RTB) infrastructure from AWS to GCP, ensuring continuous access and compliance with operational standards.
# - Implemented a seamless migration of AWS RDS databases to Google Cloud SQL, improving data accessibility and continuity without service interruption.
#
# ---
#
# ## Certifications
#
# - AWS Cloud Practitioner
# - AWS Solutions Architect Associate
# - Microsoft Certified Azure Fundamentals
# - AWS DevOps Professional
#
# ---
#
# ## Skills
#
# - **Languages**: Python, JavaScript, Node.js
# - **Cloud & IAC**: AWS (EC2, Lambda, CloudFormation), Azure (VMs, ARM), Terraform
# - **CI/CD & Automation**: Jenkins, GitHub Actions, Ansible
# - **Containers & Orchestration**: Docker, Kubernetes
# - **Data Analysis**: SQL, PostgreSQL, MySQL, and data manipulation with Python (Pandas, NumPy)
#
# ---
#
# ## Additional Suggestions
#
# 1. **Skills to Add**:
#    - Data analysis tools and techniques specific to financial performance metrics.
#    - Familiarity with compliance regulations related to drug pricing programs.
#
# 2. **Certifications or Courses**:
#    - Consider courses or certifications in Health Informatics or Healthcare Financial Management to gain relevant industry knowledge.
#
# 3. **Project Ideas or Experiences**:
#    - Develop a project focused on data analysis and reporting for a cloud-based application related to healthcare or drug pricing.
#    - Participate in case studies or internships that provide experience in managing financial data and compliance within healthcare settings.

# %%
display(Markdown(response_string))
response_list = response_string.split("## Additional Suggestions")
print(response_list[0])
# Out:
# # Udit Mohanty
#
# [Website](https://github.com/Shubh3005/AI-Builders-Bootcamp-2) | [LinkedIn](https://www.linkedin.com/in/udit-mohanty-8970011a7/)
# **Phone**: +1(562) 284-9254 | **Email**: udit.mohanty01@student.csulb.edu
# **Location**: Long Beach, CA 90815
#
# ---
#
# ## Aspiring Cloud Engineer
#
# Detail-oriented AWS Cloud Engineer with over two years of experience in managing and optimizing cloud infrastructure solutions. Proven ability to analyze data effectively and contribute to strategic decision-making while ensuring compliance with program regulations. Exceptional skills in AWS, Azure, and Infrastructure as Code (Terraform, CloudFormation). Recognized for migrating complex architectures and automating CI/CD pipelines with a strong commitment to continuous improvement in fast-paced environments. M.Sc. candidate in Information Systems with several AWS and Azure certifications.
#
# ---
#
# ## Education
#
# **California State University, Long Beach**
# _M.Sc. in Information Systems_ | Expected Graduation: May 2025
# **GPA**: 3.8/4.00
#
# ---
#
# ## Experience
#
# **Cognizant Technology Solutions**
# _DevOps Engineer_
# _April 2021 – June 2023_
#
# - Enhanced financial performance of cloud infrastructure by automating deployment pipelines with Jenkins and FluxCD, reducing deployment time by 30%.
# - Analyzed and executed a zero-downtime migration of Real-Time Bidding (RTB) infrastructure from AWS to GCP, ensuring continuous access and compliance with operational standards.
# - Implemented a seamless migration of AWS RDS databases to Google Cloud SQL, improving data accessibility and continuity without service interruption.
#
# ---
#
# ## Certifications
#
# - AWS Cloud Practitioner
# - AWS Solutions Architect Associate
# - Microsoft Certified Azure Fundamentals
# - AWS DevOps Professional
#
# ---
#
# ## Skills
#
# - **Languages**: Python, JavaScript, Node.js
# - **Cloud & IAC**: AWS (EC2, Lambda, CloudFormation), Azure (VMs, ARM), Terraform
# - **CI/CD & Automation**: Jenkins, GitHub Actions, Ansible
# - **Containers & Orchestration**: Docker, Kubernetes
# - **Data Analysis**: SQL, PostgreSQL, MySQL, and data manipulation with Python (Pandas, NumPy)
#
# ---
#
# ## Additional Suggestions
#
# 1. **Skills to Add**:
#    - Data analysis tools and techniques specific to financial performance metrics.
#    - Familiarity with compliance regulations related to drug pricing programs.
#
# 2. **Certifications or Courses**:
#    - Consider courses or certifications in Health Informatics or Healthcare Financial Management to gain relevant industry knowledge.
#
# 3. **Project Ideas or Experiences**:
#    - Develop a project focused on data analysis and reporting for a cloud-based application related to healthcare or drug pricing.
#    - Participate in case studies or internships that provide experience in managing financial data and compliance within healthcare settings.
# # Udit Mohanty
#
# [Website](https://github.com/Shubh3005/AI-Builders-Bootcamp-2) | [LinkedIn](https://www.linkedin.com/in/udit-mohanty-8970011a7/)
# **Phone**: +1(562) 284-9254 | **Email**: udit.mohanty01@student.csulb.edu
# **Location**: Long Beach, CA 90815
#
# ---
#
# ## Aspiring Cloud Engineer
#
# Detail-oriented AWS Cloud Engineer with over two years of experience in managing and optimizing cloud infrastructure solutions. Proven ability to analyze data effectively and contribute to strategic decision-making while ensuring compliance with program regulations. Exceptional skills in AWS, Azure, and Infrastructure as Code (Terraform, CloudFormation). Recognized for migrating complex architectures and automating CI/CD pipelines with a strong commitment to continuous improvement in fast-paced environments. M.Sc. candidate in Information Systems with several AWS and Azure certifications.
#
# ---
#
# ## Education
#
# **California State University, Long Beach**
# _M.Sc. in Information Systems_ | Expected Graduation: May 2025
# **GPA**: 3.8/4.00
#
# ---
#
# ## Experience
#
# **Cognizant Technology Solutions**
# _DevOps Engineer_
# _April 2021 – June 2023_
#
# - Enhanced financial performance of cloud infrastructure by automating deployment pipelines with Jenkins and FluxCD, reducing deployment time by 30%.
# - Analyzed and executed a zero-downtime migration of Real-Time Bidding (RTB) infrastructure from AWS to GCP, ensuring continuous access and compliance with operational standards.
# - Implemented a seamless migration of AWS RDS databases to Google Cloud SQL, improving data accessibility and continuity without service interruption.
#
# ---
#
# ## Certifications
#
# - AWS Cloud Practitioner
# - AWS Solutions Architect Associate
# - Microsoft Certified Azure Fundamentals
# - AWS DevOps Professional
#
# ---
#
# ## Skills
#
# - **Languages**: Python, JavaScript, Node.js
# - **Cloud & IAC**: AWS (EC2, Lambda, CloudFormation), Azure (VMs, ARM), Terraform
# - **CI/CD & Automation**: Jenkins, GitHub Actions, Ansible
# - **Containers & Orchestration**: Docker, Kubernetes
# - **Data Analysis**: SQL, PostgreSQL, MySQL, and data manipulation with Python (Pandas, NumPy)
#
# ---

# %%
display(Markdown(response_list[0]))
# Out:
# # Udit Mohanty
#
# [Website](https://github.com/Shubh3005/AI-Builders-Bootcamp-2) | [LinkedIn](https://www.linkedin.com/in/udit-mohanty-8970011a7/)
# **Phone**: +1(562) 284-9254 | **Email**: udit.mohanty01@student.csulb.edu
# **Location**: Long Beach, CA 90815
#
# ---
#
# ## Aspiring Cloud Engineer
#
# Detail-oriented AWS Cloud Engineer with over two years of experience in managing and optimizing cloud infrastructure solutions. Proven ability to analyze data effectively and contribute to strategic decision-making while ensuring compliance with program regulations. Exceptional skills in AWS, Azure, and Infrastructure as Code (Terraform, CloudFormation). Recognized for migrating complex architectures and automating CI/CD pipelines with a strong commitment to continuous improvement in fast-paced environments. M.Sc. candidate in Information Systems with several AWS and Azure certifications.
#
# ---
#
# ## Education
#
# **California State University, Long Beach**
# _M.Sc. in Information Systems_ | Expected Graduation: May 2025
# **GPA**: 3.8/4.00
#
# ---
#
# ## Experience
#
# **Cognizant Technology Solutions**
# _DevOps Engineer_
# _April 2021 – June 2023_
#
# - Enhanced financial performance of cloud infrastructure by automating deployment pipelines with Jenkins and FluxCD, reducing deployment time by 30%.
# - Analyzed and executed a zero-downtime migration of Real-Time Bidding (RTB) infrastructure from AWS to GCP, ensuring continuous access and compliance with operational standards.
# - Implemented a seamless migration of AWS RDS databases to Google Cloud SQL, improving data accessibility and continuity without service interruption.
#
# ---
#
# ## Certifications
#
# - AWS Cloud Practitioner
# - AWS Solutions Architect Associate
# - Microsoft Certified Azure Fundamentals
# - AWS DevOps Professional
#
# ---
#
# ## Skills
#
# - **Languages**: Python, JavaScript, Node.js
# - **Cloud & IAC**: AWS (EC2, Lambda, CloudFormation), Azure (VMs, ARM), Terraform
# - **CI/CD & Automation**: Jenkins, GitHub Actions, Ansible
# - **Containers & Orchestration**: Docker, Kubernetes
# - **Data Analysis**: SQL, PostgreSQL, MySQL, and data manipulation with Python (Pandas, NumPy)
#
# ---

# %%
def find_linkedin_urls(company_name, job_title, num_results=10):
    """
    Function to search for LinkedIn URLs using Google Custom Search API.
    """
    GOOGLE_API_KEY = 'AIzaSyBRmdsbuKKgzs30mcimTO3pE_MLhbZgzoI'
    CUSTOM_SEARCH_ENGINE_ID = 'e0b4e040586d4475e'

    query = f"LinkedIn {job_title} at {company_name} from {United States}"
    url = 'https://www.googleapis.com/customsearch/v1'
    params = {
        'q': query,
        'key': GOOGLE_API_KEY,
        'cx': CUSTOM_SEARCH_ENGINE_ID,
        'num': num_results,
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()

        linkedin_urls = []
        for item in data.get('items', []):
            if 'linkedin.com' in item['link']:
                linkedin_urls.append(item['link'])

        return linkedin_urls

    else:
        print("Error fetching search results")
        return []

# %%
company_name = input()
# Out:
#  amazon

# %%
job_title = input()
# Out:
#  aws cloud engineer

# %%
linkedin_urls = find_linkedin_urls(company_name, job_title)

# %%
print("LinkedIn Profiles Found:")
for url in linkedin_urls:
    print(url)
# Out:
# LinkedIn Profiles Found:
# https://www.linkedin.com/company/amazon-web-services
# https://in.linkedin.com/in/ramneekkalra
# https://www.linkedin.com/in/christopher-glenn-b2281852
# https://uk.linkedin.com/in/kprasadrao
# https://www.linkedin.com/in/aswathramas
# https://www.linkedin.com/in/michaelrishiforrester
# https://ca.linkedin.com/in/betty-wenyu-huang-b5325a146
# https://es.linkedin.com/in/igor-soroka
# https://ie.linkedin.com/in/klunlawrencechen
# https://au.linkedin.com/in/cwywgrant
